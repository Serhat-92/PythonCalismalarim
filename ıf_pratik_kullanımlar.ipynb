# %%
my_string = "Hello World"

# %%
if my_string == "Hello World":
    print("equal")
# Out:
# equal

# %%
if "Hello" in my_string:
    print("true")
else:
    print("false")
# Out:
# true

# %%
my_list = [1,2,3,4,5]

# %%
if 2 in my_list:
    print("true")
else:
    print("false")
# Out:
# true

# %%
my_dictionary = {"key1":100, "key2":200, "key":300}

# %%
if 100 in my_dictionary.keys():
    print("true")
else:
    print("false")
# Out:
# false

# %%
if 100 in my_dictionary.values():
    print("true")
else:
    print("false")
# Out:
# true

# %%
if 100 in my_dictionary:
    print("evet icinde")
elif 100 in my_dictionary.keys():
    print("evet keyslerin icinde")
elif 100 in my_dictionary.values():
    print("evet valueslerin icinde")
else:
    print("hayir icinde degil")
# Out:
# evet valueslerin icinde
