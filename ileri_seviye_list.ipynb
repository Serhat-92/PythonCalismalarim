# %% [markdown]
# nested list (iç içe geçmiş liste)

# %%
new_list = [1,4,"a"]

# %%
new_list
# Out:
# [1, 4, 'a']

# %%
new_list = [1,2,4,"a",["yusuf"]]

# %%
new_list
# Out:
# [1, 2, 4, 'a', ['yusuf']]

# %%
new_list[4]
# Out:
# ['yusuf']

# %%
nested_list = new_list[4]

# %%
nested_list
# Out:
# ['yusuf']

# %%
new_list[4] = ["yusuf",1]

# %%
new_list
# Out:
# [1, 2, 4, 'a', ['yusuf', 1]]

# %%
nested_list
# Out:
# ['yusuf']

# %%
nested_list = new_list[4]

# %%
nested_list
# Out:
# ['yusuf', 1]

# %%
new_list[4][1]
# Out:
# 1

# %%
new_list
# Out:
# [1, 2, 4, 'a', ['yusuf', 1]]

# %%
new_list[2:]
# Out:
# [4, 'a', ['yusuf', 1]]

# %%
new_list[:2]
# Out:
# [1, 2]
