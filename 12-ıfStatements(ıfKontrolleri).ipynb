# %%
if 3 > 2:
    print("321")
    print("yusufi")
# Out:
# 321
# yusufi

# %%
x = 5

# %%
y = 4

# %%
if x > y:
    print("x is greater")
else:
    print("y is greater")
# Out:
# x is greater

# %%
if x < y:
    print("x is greater")
else:
    print("y is greater")
# Out:
# y is greater

# %%
a = 3

# %%
b = 3

# %%
if a > b:
    print("a is greater")
elif a == b:
    print("a is b")
else:
    print("b is greater")
# Out:
# a is b
