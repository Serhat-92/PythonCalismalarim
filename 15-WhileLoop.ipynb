# %%
 a = 0

# %%
while a <= 5:
    print("selam")
    a = a + 1
# Out:
# selam
# selam
# selam
# selam
# selam
# selam

# %%
my_list = [1,2,3,4,5]

# %%
my_list.pop()
# Out:
# 5

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list.append(5)

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
while 3 in my_list:
    print("3 in my list")
    my_list.pop()
# Out:
# 3 in my list
# 3 in my list
# 3 in my list

# %%
number = 0

# %%
while number < 10:
    if number == 5:
        break
    print(number)
    number = number + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
while p < 10:
    if p == 2:
        print("i see u")
    else:
        pass
    print(p)
    p = p + 1
# Out:
# 0
# 1
# i see u
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
p = 0

# %%
while p < 5:
    print("value p: " + str (p))
    p += 1
# Out:
# value p: 0
# value p: 1
# value p: 2
# value p: 3
# value p: 4

# %%
a = 0

# %%
while a < 10:
    print(f"value a: {a}")
    a = a + 1
# Out:
# value a: 0
# value a: 1
# value a: 2
# value a: 3
# value a: 4
# value a: 5
# value a: 6
# value a: 7
# value a: 8
# value a: 9
