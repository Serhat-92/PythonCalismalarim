# %%
my_list = [10,20,30,40,50,60]

# %%
for number in my_list:
    print(number * 2)
# Out:
# 20
# 40
# 60
# 80
# 100
# 120

# %%
for num in my_list:
    if num == 30:
        break
    print(num * 2)
# Out:
# 20
# 40

# %%
for item in my_list:
    if item == 30:
        continue
    print(item * 2)
# Out:
# 20
# 40
# 80
# 100
# 120

# %%
for no in my_list:
    pass
