# %%
my_string = "Yusuf"

# %%
my_string[0]
# Out:
# 'Y'

# %% [markdown]
# immuatability:

# %%
#my_string[] = "B"

# %%
#my_string[] = "G"

# %% [markdown]
# Mutable:

# %%
my_list = [1,2,3]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[0] = 5

# %%
my_list
# Out:
# [5, 2, 3]

# %%
my_list[2] = 6

# %%
my_list
# Out:
# [5, 2, 6]

# %%
my_list.append(7)

# %%
my_list
# Out:
# [5, 2, 6, 7]

# %%
my_string = "lars"

# %%
my_string.capitalize()
# Out:
# 'Lars'

# %%
my_string
# Out:
# 'lars'

# %%
my_list = [1,2,3]

# %%
my_list.pop()
# Out:
# 3

# %%
my_list
# Out:
# [1, 2]

# %%
my_mixed_list = ["a","b","c",1,2,3,]

# %%
my_mixed_list
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
my_mixed_list[2]
# Out:
# 'c'

# %%
my_mixed_list[-1]
# Out:
# 3

# %%
my_mixed_list[1:]
# Out:
# ['b', 'c', 1, 2, 3]

# %%
my_mixed_list
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
my_mixed_list.append(4)

# %%
my_mixed_list
# Out:
# ['a', 'b', 'c', 1, 2, 3, 4]

# %%
my_mixed_list + my_list
# Out:
# ['a', 'b', 'c', 1, 2, 3, 4, 1, 2]

# %%
my_list_1 = ["yusuf","ahmet","yavuz"]

# %%
my_list_2 = [20,21,22]

# %%
my_list_3 = my_list_1 + my_list_2

# %%
my_list_3
# Out:
# ['ahmet', 'yavuz', 'yusuf', 20, 21, 22]

# %%
my_list_3 * 2
# Out:
# ['ahmet', 'yavuz', 'yusuf', 20, 21, 22, 'ahmet', 'yavuz', 'yusuf', 20, 21, 22]

# %%
my_list_3.reverse()

# %%
my_list_3
# Out:
# [22, 21, 20, 'yusuf', 'yavuz', 'ahmet']
