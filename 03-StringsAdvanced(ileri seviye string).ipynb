# %%
my_string = "hello world"

# %%
my_string
# Out:
# 'hello world'

# %%
##indexing

# %%
my_string[0]
# Out:
# 'h'

# %%
my_string[0]
# Out:
# 'h'

# %%
my_string[4]
# Out:
# 'o'

# %%
my_string[-1]
# Out:
# 'd'

# %%
my_string[-3]
# Out:
# 'r'

# %%
my_string_2 = "1234567890"

# %%
my_string_2[0]
# Out:
# '1'

# %%
my_string_2[2:]
# Out:
# '34567890'

# %%
##slicing

# %%
my_string_2[4:]
# Out:
# '567890'

# %%
##stoping index

# %%
my_string_2[:2]
# Out:
# '12'

# %%
my_string_2[:4]
# Out:
# '1234'

# %%
my_string_2[2:4]
# Out:
# '34'

# %%
my_string_2[4:6]
# Out:
# '56'

# %%
##step size

# %%
my_string_2[::]
# Out:
# '1234567890'

# %%
my_string_2[::3]
# Out:
# '1470'

# %%
my_string_2[::2]
# Out:
# '13579'

# %%
my_string_2[2:4:2]
# Out:
# '3'

# %%
my_string_2[::-1]
# Out:
# '0987654321'
