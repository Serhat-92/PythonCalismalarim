# %%
my_list = ["a",1,"c"]

# %%
my_list[0] = "b"

# %%
my_list
# Out:
# ['b', 1, 'c']

# %%
my_tuple = ("a",1,"c")

# %%
my_tuple[0]
# Out:
# 'a'

# %%
##immutable:

# %%
#my_tuple[0] = "b"

# %%
my_tuple.count("a")
# Out:
# 1

# %%
my_tuple_2 = (1,1,1,1,"a","a","a")

# %%
my_tuple_2.count(1)
# Out:
# 4

# %%
my_tuple_2.index("a")
# Out:
# 4

# %%
my_tuple_2.index(1)
# Out:
# 0
