# %%
my_list = [1,2,3,1]

# %%
my_list
# Out:
# [1, 2, 3, 1]

# %% [markdown]
# casting:

# %%
my_set = set(my_list)

# %%
my_set
# Out:
# {1, 2, 3}

# %%
my_set_2 = {1,2,3,3}

# %%
my_set_2
# Out:
# {1, 2, 3}

# %%
type(my_set_2)
# Out:
# set

# %%
my_set_3 = {"a","b","c","b"}

# %%
my_set_3
# Out:
# {'a', 'b', 'c'}

# %%
my_list = []

# %%
type(my_list)
# Out:
# list

# %%
my_list.append(1)

# %%
my_list
# Out:
# [1]

# %%
my_set_4 = {}

# %%
my_set_4
# Out:
# {}

# %%
type(my_set_4)
# Out:
# dict

# %%
my_set_5 = set()

# %%
my_set_5
# Out:
# set()

# %%
my_set_5.add(4)

# %%
my_set_5
# Out:
# {4}

# %%
type(my_set_5)
# Out:
# set

# %%
my_dict_2 = dict()

# %%
my_dict_2["key1"] = 1

# %%
my_dict_2
# Out:
# {'key1': 1}

# %%
my_set_10 = {}

# %%
type(my_set_10)
# Out:
# dict

# %%
my_set_11 = set(my_set_10)

# %%
my_set_11
# Out:
# set()

# %%
type(my_set_11)
# Out:
# set

# %%
type(my_set_10)
# Out:
# dict
