# %%
my_super_hero = input("superhero: ")
# Out:
# superhero:  Batman

# %%
if my_super_hero == "Batman":
    print("Batmaan")
elif my_super_hero == "Superman":
    print("Supermaan")
elif my_super_hero == "Ironman":
    print("Ironmaan")
else:
    print(":(")
# Out:
# Batmaan

# %%
my_favorite_toy = input("toy: ")
# Out:
# toy:  gun

# %%
if my_favorite_toy == "car":
    print("caaaar")
elif my_favorite_toy == "gun":
    print("baaam!!!")
elif my_favorite_toy == "my_heart":
    print("dayum")
else:
    print("sorry :(((")
# Out:
# baaam!!!

# %%
a = 10

# %%
b = 15

# %%
c = 20

# %%
if a > b or b < c:
    print("yavasyavashasansas")
elif a < b and b > c:
    print("Nejat İsler")
else:
    print("Recep Ivedik")
# Out:
# yavasyavashasansas

# %%
my_character = input("live?: ")
# Out:
# live?:  dead

# %%
if my_character == "dead":
    print("game over")
elif my_character == "alive but hurt":
    print("low hp")
else:
    print("alive")
# Out:
# game over

# %%
isDead = False

# %%
if isDead:
    print("character is dead")
else:
    print("character is not dead")
# Out:
# character is not dead

# %%
if not isDead:
    print("character is not dead")
# Out:
# character is not dead
