# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
my_boolean = True

# %%
my_boolean
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1>1
# Out:
# False

# %%
4+2>4
# Out:
# True

# %%
x = 5

# %%
y = input("y: ")
# Out:
# y:  6

# %%
type("y")
# Out:
# str

# %%
y_int = int(y)

# %%
type(y_int)
# Out:
# int

# %%
y_int
# Out:
# 6

# %%
y_int > x
# Out:
# True
