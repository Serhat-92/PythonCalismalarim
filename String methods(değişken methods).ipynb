# %%
my_name = 'yusuf'

# %%
my_name.capitalize()
# Out:
# 'Yusuf'

# %%
my_name
# Out:
# 'yusuf'

# %%
my_name_capitalize = my_name.capitalize()

# %%
my_name_capitalize
# Out:
# 'Yusuf'

# %%
my_name = "Yusuf Serhat"

# %%
my_name.split()
# Out:
# ['Yusuf', 'Serhat']

# %%
my_name
# Out:
# 'Yusuf Serhat'

# %%
my_name.find("t")
# Out:
# 11

# %%
my_name.upper()
# Out:
# 'YUSUF SERHAT'

# %%
my_name.swapcase()
# Out:
# 'yUSUF sERHAT'

# %%
my_name.startswith("Y")
# Out:
# True
